# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
X= pd.Series([24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00])

# %%
Name_c=['Allied Signal','Bankers Trust','General Mills','ITT Industries','J.P.Morgan & Co.','Lehman Brothers',
      'Marriott','MCI','Merrill Lynch','Microsoft','Morgan Stanley','Sun Microsystems','Travelers','US Airways',
      'Warner-Lambert']

# %%
plt.plot(X,Name_c)

# %%
X.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
sn.boxplot(X) #One outlier =90
# Out:
# <Axes: >

# %%
plt.figure(figsize=(6,8))
plt.pie(X,labels=Name_c,autopct='%1.0f%%')
plt.show()

# %%
X.mean()
# Out:
# 33.27133333333333

# %%
X.var()
# Out:
# 287.1466123809524

# %%
X.std()
# Out:
# 16.945400921222028

# %%
#Q1 (Normal distribution +function of random variable)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import scipy.stats as st

# %%
Z=(50-45)/8

# %%
Z
# Out:
# 0.625

# %%
Z1=st.norm.cdf(Z)

# %%
Z1
# Out:
# 0.7340144709512995

# %%
Z2=1-Z1

# %%
Z2
# Out:
# 0.26598552904870054

# %%
Z2.round(5)
# Out:
# 0.26599

# %%
#the probability that the service manager cannot meet his commitment 0.265

# %%
#Q2

# %%
#a)

# %%
#Probalability of people older than 44
P44=1-st.norm.cdf(44,38,6)
P44.round(2)
# Out:
# 0.16

# %%
#Probability of people b/w 44 and 38
P38=st.norm.cdf(44,38,6)-st.norm.cdf(38,38,6)
P38
P38.round(2)
# Out:
# 0.34

# %%
#b)

# %%
#probability of employees under age 30
P30=st.norm.cdf(30,38,6)
P30
# Out:
# 0.09121121972586788

# %%
400*P30
# Out:
# 36.484487890347154

# %%
#employees under the age of 30 at the center would be expected to attract about 36 employees IS TRUE

# %%
#q3

# %%
'''The Normal Distribution has its link with the Central Limit Theorem, which states that ‘Any large sum of independent identically distribution random variables are approximately Normal'''
# Out:
# 'The Normal Distribution has its link with the Central Limit Theorem, which states that ‘Any large sum of independent identically distribution random variables are approximately Normal'

# %%
#Q4
st.norm.interval(0.99,100,20)
# Out:
# (48.48341392902199, 151.516586070978)

# %%
#q5
mean=5+7
mean
# Out:
# 12

# %%
std=np.sqrt(9+16)

# %%
std
# Out:
# 5.0

# %%
#a)
st.norm.interval(0.95,mean*45,std*45)
# Out:
# (99.00810347848784, 980.9918965215122)

# %%
#c)
st.norm.cdf(0,5,3)
# Out:
# 0.0477903522728147

# %%
st.norm.cdf(0,7,4)
# Out:
# 0.040059156863817086

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import scipy.stats as st

# %%
st.norm.ppf(0.95,1,1)
# Out:
# 2.6448536269514724

# %%
#Q8

# %%
st.norm.ppf(0.95)
# Out:
# 1.6448536269514722

# %%
#q3 set 4

# %%
#for investigation
#1-p(45<p<55)

# %%
z=(45-50)/(40/10)

# %%
z
# Out:
# -1.25

# %%
Z=(55-50)/(40/10)

# %%
Z
# Out:
# 1.25

# %%
a=st.norm.cdf(Z)-st.norm.cdf(z)

# %%
a
# Out:
# 0.7887004526662893

# %%
#for no investigation
1-a
# Out:
# 0.2112995473337107
